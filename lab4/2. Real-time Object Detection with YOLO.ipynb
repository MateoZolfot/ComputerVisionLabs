# %% [markdown]
# # **Tutorial:** Real-time Object Detection with YOLO

# %% [markdown]
# In this tutorial, you will learn how to use the YOLOv11 model with OpenCV to automatically detect and draw bounding boxes around objects in an image.

# %% [markdown]
# ### **Step 1: Install Required Packages**

# %% [markdown]
# Install the necessary packages including OpenCV and other dependencies:

# %%
# %pip install --upgrade ultralytics
# %pip install opencv-python
# %pip install matplotlib
#%pip install numpy==1.26.4 --force-reinstall
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.21-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: numpy>=1.23.0 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from ultralytics) (2.2.6)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from ultralytics) (3.10.8)
# Requirement already satisfied: opencv-python>=4.6.0 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from ultralytics) (12.1.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from ultralytics) (2.32.5)
# Collecting scipy>=1.4.1 (from ultralytics)
#   Downloading scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: torch>=1.8.0 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from ultralytics) (2.10.0+cpu)
# Requirement already satisfied: torchvision>=0.9.0 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from ultralytics) (0.25.0+cpu)
# Requirement already satisfied: psutil>=5.8.0 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from ultralytics) (7.2.2)
# Collecting polars>=0.20.0 (from ultralytics)
#   Downloading polars-1.39.0-py3-none-any.whl.metadata (10 kB)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=3 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Collecting polars-runtime-32==1.39.0 (from polars>=0.20.0->ultralytics)
#   Downloading polars_runtime_32-1.39.0-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: six>=1.5 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2026.1.4)
# Requirement already satisfied: filelock in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2026.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.21-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 7.8 MB/s  0:00:00
# Downloading polars-1.39.0-py3-none-any.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.9/823.9 kB 10.4 MB/s  0:00:00
# Downloading polars_runtime_32-1.39.0-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (46.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 MB 10.2 MB/s  0:00:04m0:00:0100:01
# Downloading scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 8.1 MB/s  0:00:04m0:00:0100:01
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: scipy, polars-runtime-32, polars, ultralytics-thop, ultralytics
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [ultralytics] [ultralytics]me-32]
# Successfully installed polars-1.39.0 polars-runtime-32-1.39.0 scipy-1.15.3 ultralytics-8.4.21 ultralytics-thop-2.0.18
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: opencv-python in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from opencv-python) (2.2.6)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Verify the installations:

# %%
# %pip show opencv-python ultralytics
# Out:
# Name: opencv-python
# Version: 4.13.0.92
# Summary: Wrapper package for OpenCV python bindings.
# Home-page: https://github.com/opencv/opencv-python
# Author:
# Author-email:
# License: Apache 2.0
# Location: /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages
# Requires: numpy
# Required-by: ultralytics
# ---
# Name: ultralytics
# Version: 8.4.21
# Summary: Ultralytics YOLO 🚀 for SOTA object detection, multi-object tracking, instance segmentation, pose estimation and image classification.
# Home-page: https://ultralytics.com
# Author:
# Author-email: Glenn Jocher <glenn.jocher@ultralytics.com>, Jing Qiu <jing.qiu@ultralytics.com>
# License: AGPL-3.0
# Location: /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages
# Requires: matplotlib, numpy, opencv-python, pillow, polars, psutil, pyyaml, requests, scipy, torch, torchvision, ultralytics-thop
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### **Step 2: Import Required Libraries**

# %% [markdown]
# Import the libraries you will use:

# %%
import numpy as np
import math
import cv2
from ultralytics import YOLO
from matplotlib import pyplot as plt

# %% [markdown]
# ### **Step 3: Load the YOLOv11 Model**

# %% [markdown]
# Load the pre-trained YOLOv11 model (automatically downloads if not available):

# %%
# Load a pretrained YOLO model version 11, nano (n) size
model = YOLO('yolo26n.pt')  # Using nano version for speed, other options: yolov11s.pt (small), yolov11m.pt (medium), yolov11l.pt (large), yolov11x.pt (extra large)

# %%
# Show class names the model can detect 
model.names
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
#  57: 'couch',
#  58: 'potted plant',
#  59: 'bed',
#  60: 'dining table',
#  61: 'toilet',
#  62: 'tv',
#  63: 'laptop',
#  64: 'mouse',
#  65: 'remote',
#  66: 'keyboard',
#  67: 'cell phone',
#  68: 'microwave',
#  69: 'oven',
#  70: 'toaster',
#  71: 'sink',
#  72: 'refrigerator',
#  73: 'book',
#  74: 'clock',
#  75: 'vase',
#  76: 'scissors',
#  77: 'teddy bear',
#  78: 'hair drier',
#  79: 'toothbrush'}

# %% [markdown]
# ### **Step 4.1: Run YOLO on your webcam video (the simple way)**

# %%
# Run YOLO model on your webcam
results = model.predict(
    source=0, # source=0 uses the default webcam, use source=1 for an external camera
    show=True, # show=True to display the video feed with detections in a window 
    stream=True, # stream=True for real-time processing of video frames
    imgsz=256, # resize frames to 256x256 for faster processing and lower resource usage
    vid_stride=3, # process every 3rd frame to reduce CPU/GPU load
    save=False # do not save the video output (this saves disk space and speeds up processing)
    #verbose=False # stops printing per-frame logs
    #conf=0.3, # confidence threshold of 30% (default is 0.25). Adjust as needed.
)
# Out:
# QFontDatabase: Cannot find font directory /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.

# %% [markdown]
# ### **Step 4.2: Run YOLO on your webcam video (the complete way)**

# %%
# Configure video capture from the camera
capture = cv2.VideoCapture(0)  # Open the default camera

# Define class names (YOLO COCO dataset classes)
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"]

# Set the image width and height
capture.set(cv2.CAP_PROP_FRAME_WIDTH, 640)  # Image width
capture.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)  # Image height

# Start a loop to process camera frames
while True:
    success, img = capture.read()  # Capture a frame

    # Perform object detection on the captured image (using the pre-trained YOLO model we loaded earlier)
    results = model(img, stream=True)  # Stream generator to process detection results in real time

    # Process the detection results (we can have multiple objects detected in a single frame)
    for r in results:
        boxes = r.boxes

        # Iterate over the detected bounding boxes
        for box in boxes:
            # Get the bounding box coordinates in xyxy format
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)  # Convert to integer values

            # Draw the bounding box on the image
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 1)

            # Get the detection confidence (value between 0 and 1) and round to two decimal places
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->", confidence)

            # Get the numeric identifier of the detected class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # Display the class name next to the bounding box
            org = [x1, y1]  # Coordinates of the top-left corner for the text
            font = cv2.FONT_HERSHEY_SIMPLEX # Font type
            fontScale = 1  # Font scale
            color = (255, 0, 0)  # Color: Blue (BGR format)
            thickness = 1  # Text line thickness
            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    # Display the image with a window name and the processed image with detections
    cv2.imshow('YOLO Detection', img)

    # Exit the loop if the 'q' key is pressed
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

# Release the camera and close all windows
capture.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 172.9ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 6.2ms preprocess, 172.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
# QFontDatabase: Cannot find font directory /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# 0: 480x640 1 person, 236.9ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 14.2ms preprocess, 236.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 137.8ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 39.4ms preprocess, 137.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.0ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 2.8ms preprocess, 122.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 294.0ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 11.5ms preprocess, 294.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 143.2ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 6.4ms preprocess, 143.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 101.5ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.7ms preprocess, 101.5ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 104.4ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 3.4ms preprocess, 104.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 127.6ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 2.7ms preprocess, 127.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 89.2ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.3ms preprocess, 89.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 86.5ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 5.7ms preprocess, 86.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.5ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.7ms preprocess, 84.5ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 80.3ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 2.9ms preprocess, 80.3ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 89.0ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.5ms preprocess, 89.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 93.6ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 2.5ms preprocess, 93.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 93.6ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.5ms preprocess, 93.6ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 91.4ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.6ms preprocess, 91.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 76.7ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.8ms preprocess, 76.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 86.7ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 2.5ms preprocess, 86.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.3ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.3ms preprocess, 83.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 80.9ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 5.9ms preprocess, 80.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 81.0ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.7ms preprocess, 81.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.1ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.0ms preprocess, 83.1ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 106.4ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.6ms preprocess, 106.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.7ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.9ms preprocess, 84.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 79.2ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.2ms preprocess, 79.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 69.2ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.1ms preprocess, 69.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.8ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 4.7ms preprocess, 84.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 80.3ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.0ms preprocess, 80.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.2ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.1ms preprocess, 83.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 87.8ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.3ms preprocess, 87.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 90.4ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 4.1ms preprocess, 90.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 81.2ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 7.0ms preprocess, 81.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 77.2ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.2ms preprocess, 77.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.9ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 2.9ms preprocess, 83.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.4ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.7ms preprocess, 83.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 79.5ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 2.3ms preprocess, 79.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 108.5ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 4.3ms preprocess, 108.5ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 70.0ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.7ms preprocess, 70.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.9ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.5ms preprocess, 84.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 80.6ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 3.0ms preprocess, 80.6ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 87.3ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 2.0ms preprocess, 87.3ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.7ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 4.7ms preprocess, 83.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 92.8ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 1.7ms preprocess, 92.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 88.9ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.1ms preprocess, 88.9ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 81.0ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.8ms preprocess, 81.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 69.4ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.9ms preprocess, 69.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 traffic light, 106.3ms
# Confidence ---> 0.96
# Class name --> person
# Confidence ---> 0.39
# Class name --> traffic light
# Speed: 8.1ms preprocess, 106.3ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 80.2ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.3ms preprocess, 80.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.3ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.5ms preprocess, 84.3ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 85.8ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 3.1ms preprocess, 85.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 77.2ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.8ms preprocess, 77.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.5ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.4ms preprocess, 84.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 traffic light, 95.4ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.3
# Class name --> traffic light
# Speed: 1.4ms preprocess, 95.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 traffic light, 112.4ms
# Confidence ---> 0.96
# Class name --> person
# Confidence ---> 0.3
# Class name --> traffic light
# Speed: 1.3ms preprocess, 112.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 92.9ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 10.5ms preprocess, 92.9ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 86.9ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 2.6ms preprocess, 86.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 traffic light, 84.2ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.27
# Class name --> traffic light
# Speed: 3.4ms preprocess, 84.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.4ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 5
7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 82.3ms
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Speed: 2.3ms preprocess, 82.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 80.0ms
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Speed: 1.9ms preprocess, 80.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 72.8ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Speed: 4.0ms preprocess, 72.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 84.6ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Speed: 2.4ms preprocess, 84.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 81.8ms
# Confidence ---> 0.67
# Class name --> person
# Speed: 1.8ms preprocess, 81.8ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 82.1ms
# Confidence ---> 0.66
# Class name --> person
# Speed: 1.6ms preprocess, 82.1ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 81.9ms
# Confidence ---> 0.75
# Class name --> person
# Speed: 2.2ms preprocess, 81.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 127.5ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Speed: 3.6ms preprocess, 127.5ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 102.9ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 4.1ms preprocess, 102.9ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 74.7ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 2.6ms preprocess, 74.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 80.8ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Speed: 1.6ms preprocess, 80.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 80.9ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 2.3ms preprocess, 80.9ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 73.7ms
# Confidence ---> 0.45
# Class name --> person
# Speed: 1.5ms preprocess, 73.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 86.4ms
# Confidence ---> 0.59
# Class name --> person
# Speed: 2.9ms preprocess, 86.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 80.3ms
# Confidence ---> 0.71
# Class name --> person
# Speed: 6.9ms preprocess, 80.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 146.1ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 2.2ms preprocess, 146.1ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 88.4ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.4ms preprocess, 88.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 99.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 5.8ms preprocess, 99.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 88.0ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.4ms preprocess, 88.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.7ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 2.1ms preprocess, 84.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 77.9ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 6.4ms preprocess, 77.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.4ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 2.5ms preprocess, 83.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 85.2ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.7ms preprocess, 85.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 80.5ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 4.0ms preprocess, 80.5ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 79.9ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 6.6ms preprocess, 79.9ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 77.3ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 3.0ms preprocess, 77.3ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 86.6ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 2.4ms preprocess, 86.6ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 85.6ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 1.5ms preprocess, 85.6ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 78.3ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 4.1ms preprocess, 78.3ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 88.7ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 2.3ms preprocess, 88.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.2ms
# Confidence ---> 0.96
# Class name --> person
# Speed: 8.7ms preprocess, 84.2ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)

# %% [markdown]
# ### **Step 5.1: Run YOLO on an Image (the simple way)**

# %%
# Run yolo model on an image
results = model.predict(source="/home/mateo/Documentos/Computer_Vision/UC.04 Object Detection/Object Detection/cat.jpg", show=True)
# Out:
# image 1/1 /home/mateo/Documentos/Computer_Vision/UC.04 Object Detection/Object Detection/cat.jpg: 640x640 1 cat, 196.7ms
# Speed: 10.5ms preprocess, 196.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)

# %% [markdown]
# ### **Step 5.2: Run YOLO on an Image (the complete way)**

# %% [markdown]
# Load your image and prepare it for inference:

# %%
# Load an image (change the path to your image file)
image_bgr = cv2.imread('/home/mateo/Documentos/Notebooks_ArtificialIntelligence/5. Computer Vision/Object Detection/cat.jpg')
# Out:
# [ WARN:0@90.741] global loadsave.cpp:278 findDecoder imread_('/home/mateo/Documentos/Notebooks_ArtificialIntelligence/5. Computer Vision/Object Detection/cat.jpg'): can't open/read file: check file path/integrity

# %% [markdown]
# Run inference

# %%
# Run inference
results = model(image_bgr)
# Out:
# WARNING ⚠️ 'source' is missing. Using 'source=/home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages/ultralytics/assets'.
#
# image 1/2 /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages/ultralytics/assets/bus.jpg: 640x480 4 persons, 1 bus, 191.2ms
# image 2/2 /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages/ultralytics/assets/zidane.jpg: 384x640 2 persons, 1 tie, 143.0ms
# Speed: 10.0ms preprocess, 167.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)

# %%
# Extract detection results
boxes = results[0].boxes  # Bounding boxes
scores = boxes.conf       # Confidence scores
class_ids = boxes.cls     # Class IDs

# Create a copy of the original image to draw on
image_with_boxes = results[0].orig_img.copy()

# Define colors for different classes
colors = [(0, 255, 0), (0, 0, 255), (255, 0, 0), (255, 255, 0), 
          (0, 255, 255), (255, 0, 255), (255, 165, 0), (128, 0, 128)]

# Draw bounding boxes and labels for each detection
for i, (box, score, class_id) in enumerate(zip(boxes.xyxy, scores, class_ids)):
    # Convert tensor to numpy array
    x1, y1, x2, y2 = box.cpu().numpy()
    class_id = int(class_id.cpu().numpy())
    score = float(score.cpu().numpy())
    
    # Get class name and color
    class_name = model.names[class_id]
    color = colors[class_id % len(colors)]
    
    # Draw bounding box
    cv2.rectangle(image_with_boxes, (int(x1), int(y1)), (int(x2), int(y2)), color, 5)
    
    # Create label text
    label = f"{class_name}: {score:.2f}"
    
    # Calculate text position
    label_size = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 1, 2)[0]
    label_y = max(int(y1) - 10, label_size[1] + 10)
    
    # Draw text background
    cv2.rectangle(image_with_boxes, 
                 (int(x1), label_y - label_size[1] - 10),
                 (int(x1) + label_size[0], label_y + 5),
                 color, -1)
    
    # Draw text
    cv2.putText(image_with_boxes, label, 
               (int(x1), label_y - 5), 
               cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
    
# Convert from BGR to RGB for matplotlib
image_with_boxes_rgb = cv2.cvtColor(image_with_boxes, cv2.COLOR_BGR2RGB)

# Display the result
plt.figure(figsize=(12, 10))
plt.imshow(image_with_boxes_rgb)
plt.title('Object Detection with YOLOv11')
plt.axis('off')
plt.show()

# Print detection summary
print(f"Detected {len(boxes)} objects:")
for i, (class_id, score) in enumerate(zip(class_ids, scores)):
    class_id = int(class_id.cpu().numpy())
    score = float(score.cpu().numpy())
    print(f"  {i+1}. {model.names[class_id]} (confidence: {score:.2f})")
# Out:
# Detected 5 objects:
#   1. bus (confidence: 0.92)
#   2. person (confidence: 0.91)
#   3. person (confidence: 0.91)
#   4. person (confidence: 0.87)
#   5. person (confidence: 0.53)

# %% [markdown]
# ### **Step 6.1: Run Object Detection on a saved video (the simple way)**

# %% [markdown]
# Inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos.

# %%
# YOLO on a saved video
results = model.predict(source='/home/mateo/Documentos/Computer_Vision/UC.04 Object Detection/Object Detection/car-detection.mp4', show=True, stream=True)

# %% [markdown]
# ### **Step 6.2: Run Object Detection on a saved video (the complete way)**

# %%
# Load YOLO model
model = YOLO('/home/mateo/Documentos/Computer_Vision/UC.04 Object Detection/Object Detection/yolo26n.pt')

# Configure your video path
#video_path = "/Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/Object Detection/fruit-and-vegetable-detection.mp4"
#video_path = "/Users/eugenio/Documents/Computer_Vision/UC.04 Object Detection/Object Detection/car-detection.mp4"
video_path = "/home/mateo/Documentos/Computer_Vision/UC.04 Object Detection/Object Detection/worker-zone-detection.mp4"

# Open video
cap = cv2.VideoCapture(video_path)

# Verify video opened correctly
if not cap.isOpened():
    print("Error: Could not open video. Check the path.")
else:
    print("Video loaded successfully. Press 'q' to exit.")
    
    # Process each video frame
    while True:
        ret, frame = cap.read()
        
        if not ret:
            break  # Finish when video ends
            
        # Run detection with YOLO
        results = model(frame)
        
        # Draw bounding boxes
        for result in results:
            boxes = result.boxes
            for box in boxes:
                x1, y1, x2, y2 = map(int, box.xyxy[0].cpu().numpy())
                confidence = float(box.conf[0].cpu().numpy())
                class_id = int(box.cls[0].cpu().numpy())
                
                # Only show detections with confidence > 50%
                if confidence > 0.5:
                    # Draw rectangle
                    cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                    
                    # Show label
                    label = f"{model.names[class_id]}: {confidence:.2f}"
                    cv2.putText(frame, label, (x1, y1-10), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
        
        # Show frame with detections
        cv2.imshow('Object Detection', frame)
        
        # Exit with 'q' key
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

# Release resources
cap.release()
cv2.destroyAllWindows()
print("Processing completed.")
# Out:
# Video loaded successfully. Press 'q' to exit.
#
# 0: 384x640 1 person, 116.0ms
# Speed: 5.6ms preprocess, 116.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 116.7ms
# Speed: 12.8ms preprocess, 116.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 91
6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing completed.

# %% [markdown]
# ## **Activity**
#
# ### **Option 1: Mathematics Track**
#
# Clone your repository from GitHub and run the system directly on the Jetson Nano.
#
# #### Access to the Jetson Nano
#
# You will be provided with:
# - Username
# - Jetson Nano IP address
# - Password
#
# Use your computer's terminal to connect:
#
# `ssh username@jetson_ip`
#
# #### 1. Clone the repository
# `git clone https://github.com/user/repository.git`
#
# #### 2. Access the project directory
# `cd repository`
#
# #### 3. Create virtual environment and install dependencies
# `python3 -m venv env`
# `source env/bin/activate`
# `pip install -r requirements.txt`
#
# #### 4. Run the virtual environment
# `python YOLO-Real-Time.py`
#
# ### **Grading Rubric**
#
# | **Criteria** | **Points** | **Description** |
# |-------------|-----------|----------------|
# | **1. SSH Connection** | 2 | Successfully establishes SSH connection to Jetson Nano. Properly handles authentication and connection setup. |
# | **2. Environment Setup** | 3 | Creates virtual environment and installs all dependencies correctly. Resolves any platform-specific issues. |
# | **3. Application Execution** | 3 | Runs YOLO real-time detection successfully on Jetson Nano. Handles hardware acceleration properly. |
# | **4. Performance Optimization** | 2 | Implements optimizations for Jetson Nano hardware. Maintains acceptable frame rate for real-time detection. |
#
# Total: 10 points

# %%
# Write your code here...

# %% [markdown]
# ### **Option 2: Computer Science Track**
#
# Create a Dockerfile in your Jetson Nano folder:
#
# #### Dockerfile
#
# `FROM nvcr.io/nvidia/l4t-pytorch:r32.7.1-pth1.11-py3`
# `RUN apt-get update && apt-get install -y python3-pip libopencv-dev`
# `RUN pip3 install ultralytics opencv-python`
#
# `COPY . /app`
# `WORKDIR /app`
#
# `CMD ["python3", "YOLO-Real-Time.py"]`
#
# #### 1. Clone your repository
# `git clone https://github.com/user/repository.git`
# `cd repository`
#
# #### 2. Build the Docker image
# `sudo docker build -t yolov8-detector .`
#
# #### 3. Run the container
# `sudo docker run --rm -it --net=host --device=/dev/video0 yolov8-detector`
#
# ### Steps to build and run:
#
# #### 1. Clone your repository
# `git clone https://github.com/user/repository.git`
# `cd repository`
#
# #### 2. Build the Docker image
# `sudo docker build -t yolov8-detector .`
#
# #### 3. Run the container
# `sudo docker run --rm -it --net=host --device=/dev/video0 yolov8-detector`
#
# ### **Grading Rubric**
#
# | **Criteria** | **Points** | **Description** |
# |-------------|-----------|----------------|
# | **1. Repository Setup** | 2 | Successfully clones repository and sets up environment. All dependencies installed correctly without errors. |
# | **2. Docker Implementation** | 3 | Dockerfile is properly configured with all necessary dependencies. Image builds successfully without errors. |
# | **3. Container Execution** | 3 | Container runs successfully with camera access. Real-time detection works properly in Docker environment. |
# | **4. System Performance** | 2 | Application runs smoothly with acceptable frame rate. Handles video streaming without crashes or major issues. |
#
# Total: 10 points

# %%
# Write your code here...

# %% [markdown]
# ### **Option 3: Master's in Artificial Intelligence / Data Science**
#
# In this option, the work will be developed **locally on your personal computers**.
#
# #### Objective
# Design a **specific object detection application** using YOLO (You Only Look Once), focused on **a limited subset of classes**. The system must show that **it only detects the activated classes**, visually ignoring objects belonging to deactivated classes (even if they are present in the image).
#
# #### Instructions
#
# 1. **Define a concrete application and the problem it solves**, for example: vehicle detection, fruits detection, etc.
# 2. **Select between 2 and 4 classes** from the YOLOv26 model to detect.
# 3. **Modify the model logic** or post-processing so that **only the selected classes are shown**.
# 4. Run the application on video where **objects from non-activated classes** are also present to demonstrate that the system **ignores those classes**.
# 5. Show the results clearly, visually indicating the detected and non-detected objects.
#
# #### Technical Requirements
#
# - Use `ultralytics` with `YOLO` in any version.
# - You have to use your webcam (no static images nor local video allowed).
#
# #### Deliverable
#
# Must be uploaded to the virtual classroom:
#
# - **Jupyter Notebook in PDF format** containing:
# - Commented code
# - Application title and the problem it solves
# - List of activated classes
# - Screenshots or test images with results showing:
#   - Objects *correctly detected* according to the activated classes.
#   - Objects *not detected* because they belong to deactivated classes (even if present in the image).
#
# ### **Grading Rubric**
#
# | **Criteria** | **Points** | **Description** |
# |-------------|-----------|----------------|
# | **1. Application Definition and Problem Statement** | 1 | Clearly defines a specific object detection application and its practical use case. Selects appropriate classes for the application context. |
# | **2. Class Selection and Justification** | 1 | Selects between 2-4 relevant classes from YOLOv8 model. Demonstrates thoughtful choice of classes for the specific application. |
# | **3. Implementation** | 4 | Successfully modifies the model logic or post-processing to only show selected classes. Code is functional and properly ignores non-selected classes. |
# | **4. Testing & Evidence** | 3 | Provides a clear test showing both detected (activated classes) and ignored (deactivated classes) objects. Evidence demonstrates the filtering works correctly. |
# | **5. Documentation** | 1 | Delivers complete documentation including PDF notebook, application title, class list, and proper screenshots. Submission is well-organized and professional. |
#
# Total: 10 points

# %%
import cv2
import math
from ultralytics import YOLO

# Cargar el modelo YOLO (asegúrate de usar el modelo de tu entorno, ej. yolov8n.pt o yolo11n.pt)
model = YOLO('yolov8s.pt') 
class_names = model.names

# =====================================================================
# 3. IMPLEMENTATION: Filtering Logic
# Solo estas clases serán procesadas y mostradas en pantalla
clases_permitidas = ['laptop', 'keyboard', 'mouse', 'cell phone']
# =====================================================================

capture = cv2.VideoCapture(0)
capture.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
capture.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)

window_name = 'Workspace Device Tracker'
cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)

while capture.isOpened():
    success, img = capture.read()
    if not success:
        break
        
    # Realizar detección en el frame actual
    results = model(img, stream=True, verbose=False)
    
    for r in results:
        boxes = r.boxes
        for box in boxes:
            cls = int(box.cls[0])
            class_name = class_names[cls]
            
            # =====================================================================
            # POST-PROCESSING MODIFICATION
            # Ignora cualquier objeto que no esté en la lista de clases permitidas
            if class_name in clases_permitidas:
            # =====================================================================
                
                x1, y1, x2, y2 = box.xyxy[0]
                x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
                
                # Dibujar la caja delimitadora en verde
                cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
                confidence = float(box.conf[0])
                label = f'{class_name}: {confidence:.2f}'
                
                # Configurar y dibujar el texto
                t_size = cv2.getTextSize(label, 0, fontScale=0.6, thickness=1)[0]
                c2 = x1 + t_size[0], y1 - t_size[1] - 3
                cv2.rectangle(img, (x1, y1), c2, (0, 255, 0), -1)
                cv2.putText(img, label, (x1, y1 - 2), 0, 0.6, (0, 0, 0), thickness=1)
                
    cv2.imshow(window_name, img)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

capture.release()
cv2.destroyAllWindows()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 100% ━━━━━━━━━━━━ 21.5MB 54.3MB/s 0.4s0.3s<0.1ss

# %% [markdown]
# <p style="text-align: right; font-size:14px; color:gray;">
# <b>Prepared by:</b><br>
# Manuel Eugenio Morocho-Cayamcela
# </p>
