# %% [markdown]
# # **Tutorial:** Drawing a Bounding Box with OpenCV

# %% [markdown]
# In this tutorial, you will learn how to use the OpenCV library in Python to load an image and draw a bounding box around an object. This is a fundamental step before moving on to object detection with YOLO.

# %% [markdown]
# ### **Step 1: Install OpenCV**
#
# If you don't have OpenCV installed, you can install it using pip:

# %%
# %pip install --upgrade opencv-python 
# %pip install --upgrade matplotlib
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.13.0.92-cp37-abi3-manylinux_2_28_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=2 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from opencv-python) (2.2.6)
# Downloading opencv_python-4.13.0.92-cp37-abi3-manylinux_2_28_x86_64.whl (72.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 12.9 MB/s  0:00:05m0:00:0100:01
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.13.0.92
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Verify the installed version number:

# %%
# %pip show opencv-python
# Out:
# Name: opencv-python
# Version: 4.13.0.92
# Summary: Wrapper package for OpenCV python bindings.
# Home-page: https://github.com/opencv/opencv-python
# Author:
# Author-email:
# License: Apache 2.0
# Location: /home/mateo/miniconda3/envs/vision_computacional/lib/python3.10/site-packages
# Requires: numpy
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### **Step 2: Import Required Libraries**
#
# Import the libraries you will use:

# %%
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# ### **Step 3: Load the Image**
#
# Use OpenCV's `imread` function to load your image.
#
# Replace the path with the location of your image file.

# %%
# Load the image (change the path to your image file)
image_bgr = cv2.imread('/home/mateo/Documentos/Computer_Vision/UC.04 Object Detection/Object Detection/cat.jpg')

# %%
# Print the shape of the image (height, width, channels)
print('Image shape:', image_bgr.shape)
# Out:
# Image shape: (960, 940, 3)

# %% [markdown]
# ### **Step 4: Show the image**

# %%
# Convert BGR to RGB for displaying with matplotlib
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# Display the image
plt.imshow(image_rgb)
plt.show()

# %% [markdown]
# ### **Step 5: Create the Bounding Box over the Image**
#
# To draw a bounding box, use OpenCV's `rectangle` function.
#
# You need to specify the coordinates of the **top-left** point $(x1, y1)$ and the **bottom-right** point $(x2, y2)$ of the bounding box.
#
# The coordinates should be within the image dimensions

# %%
x1, y1 = 250, 200  # Top-left corner
x2, y2 = 700, 900  # Bottom-right corner

# Draw the bounding box on the input image using cv2.rectangle
# Arguments: image, (x1, y1), (x2, y2), bounding box color in BGR, thickness
image_bgr_box = cv2.rectangle(image_bgr, (x1, y1), (x2, y2), (0, 255, 0), 15)  # Green box, thickness 15

# %% [markdown]
# ### **Step 6: Display the Image and Bounding Box**
#
# Finally, use matplotlib to display the image with the bounding box.

# %%
# Convert the image from BGR (OpenCV format) to RGB (matplotlib format)
image_rgb_box = cv2.cvtColor(image_bgr_box, cv2.COLOR_BGR2RGB)

# Display the image
plt.imshow(image_rgb_box)
plt.show()

# %% [markdown]
# You should now see your image with a bounding box drawn around the object.
#
# You can adjust the bounding box coordinates as needed to fit the object you want to highlight.

# %% [markdown]
# ### **Individual Activity:**

# %% [markdown]
# 1. Load an image containing **at least three different objects from different classes** using `cv2.imread`.

# %%
# Load the image (change the path to your image file)
image_t = cv2.imread('/home/mateo/Documentos/Computer_Vision/UC.04 Object Detection/Object Detection/cebolla.jpeg')

# %%
# Print the shape of the image (height, width, channels)
print('Image shape:', image_t.shape)
# Out:
# Image shape: (183, 276, 3)

# %%
# Convert BGR to RGB for displaying with matplotlib
image_t = cv2.cvtColor(image_t, cv2.COLOR_BGR2RGB)

# Display the image
plt.imshow(image_t)
plt.show()

# %% [markdown]
# 2. Draw **different colored bounding boxes** around each object (at least one of the bounding boxes should be yellow). Use a **line thickness** of 5 for both bounding boxes.

# %%
x1, y1 = 25, 50  # Top-left corner
x2, y2 = 200, 125  # Bottom-right corner

# Draw the bounding box on the input image using cv2.rectangle
# Arguments: image, (x1, y1), (x2, y2), bounding box color in BGR, thickness
image_t_box = cv2.rectangle(image_t, (x1, y1), (x2, y2), (0, 255, 0), 15)  # Green box, thickness 15

# %%
# Convert the image from BGR (OpenCV format) to RGB (matplotlib format)
image_t_box = cv2.cvtColor(image_t_box, cv2.RGB)

# Display the image
plt.imshow(image_t_box)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 2
#       1 # Convert the image from BGR (OpenCV format) to RGB (matplotlib format)
# ----> 2 image_t_box = cv2.cvtColor(image_t_box, cv2.RGB)
#       4 # Display the image
#       5 plt.imshow(image_t_box)
#
# AttributeError: module 'cv2' has no attribute 'RGB'

# %%
# Write your code here...
# Draw bounding boxes around three objects with different colors
# Object 1: Red bounding box
x1_obj1, y1_obj1 = 20, 30
x2_obj1, y2_obj1 = 80, 100
cv2.rectangle(image_bgr, (x1_obj1, y1_obj1), (x2_obj1, y2_obj1), (0, 0, 255), 5)

# Object 2: Yellow bounding box
x1_obj2, y1_obj2 = 100, 50
x2_obj2, y2_obj2 = 170, 140
cv2.rectangle(image_bgr, (x1_obj2, y1_obj2), (x2_obj2, y2_obj2), (0, 255, 255), 5)

# Object 3: Blue bounding box
x1_obj3, y1_obj3 = 200, 20
x2_obj3, y2_obj3 = 270, 120
cv2.rectangle(image_bgr, (x1_obj3, y1_obj3), (x2_obj3, y2_obj3), (255, 0, 0), 5)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], shape=(183, 276, 3), dtype=uint8)

# %% [markdown]
# 3. Add **text labels** above each bounding box (e.g., “Cat”, “Ball”, etc.) using `cv2.putText`.

# %%
# Write your code here...

# %% [markdown]
# 4. Display the **resulting image**.

# %%
# Write your code here...

# %% [markdown]
# 5. Suggest one method (written, no code) to **detect objects automatically** in an image (no manual coordinates). Name the model or technique you would use and briefly explain how it produces bounding boxes.

# %% [markdown]
# Write your answer here...

# %% [markdown]
# ### **Grading Rubric:**

# %% [markdown]
# | **Criteria** | **Points** | **Description** |
# |-------------|-----------|----------------|
# | **1. Image Loading** | 1 | Successfully loads an image with at least three objects using `cv2.imread`. Correct file path and proper handling of image object. |
# | **2. Bounding Boxes** | 3 | Draws **different colored bounding boxes** around each object. Boxes have correct size and position, and line thickness is set to 5. |
# | **3. Text Labels** | 2 | Adds **accurate text labels** above each bounding box using `cv2.putText`. Labels are readable and positioned correctly. |
# | **4. Automatic Detection Suggestion** | 4 | Provides a clear and reasonable method to detect objects automatically. Shows understanding of dynamic object detection. |
#
# Total: 10 points

# %% [markdown]
# <p style="text-align: right; font-size:14px; color:gray;">
# <b>Prepared by:</b><br>
# Manuel Eugenio Morocho-Cayamcela
# </p>
